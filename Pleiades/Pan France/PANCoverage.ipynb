# %%
import ipyleaflet

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, Polygon

# %%
# La Grau Pleiades coverage

#General Location
center = [43.610052, 5.113754]
zoom = 11

# Precise Location & Coverage of the Pleiades MS imagery from the .xml file
polygon = Polygon(
    locations=[(43.65609579706285,5.051026499012323), 
               (43.66174585193819,5.188620066897482), 
               (43.55582742531522,5.188676141754719),
               (43.5498155621433,5.05175914888745)],
    
    color="red",
    fill_color="red"
)


m = Map(basemap=basemaps.OpenStreetMap.France, center=center, zoom=zoom)

m.add(polygon);

m
# Out:
# Map(center=[43.610052, 5.113754], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', …
